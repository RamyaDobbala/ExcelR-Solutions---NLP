# %% [markdown]
# <a href="https://colab.research.google.com/github/RamyaDobbala/ExcelR-Solutions---NLP/blob/main/24_02_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

reviews_datasets = pd.read_csv("/content/Reviews.csv")
reviews_datasets = reviews_datasets.head(10000)
reviews_datasets.dropna()
# Out:
#          Id   ProductId          UserId                      ProfileName  \
# 0         1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1         2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2         3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3         4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4         5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...     ...         ...             ...                              ...
# 3957  94236  B004AQPNP2  A3A2RYGP3U21TX                           Glynda
# 3958  94237  B004AQPNP2  A14C2QCBNN7OXD                          BonnieB
# 3959  94238  B004AQPNP2  A1TBZWJ610IHOF                    Larry Smotrys
# 3960  94239  B004AQPNP2  A28PHNZRH8QONQ           JOHN STCLAIR "bookman"
# 3961  94240  B004AQPNP2  A2HPTZ7GMZPSG1                         Danielle
#
#       HelpfulnessNumerator  HelpfulnessDenominator  Score          Time  \
# ...

# %%
reviews_datasets['Text'][350]
# Out:
# 'These chocolate covered espresso beans are wonderful!  The chocolate is very dark and rich and the "bean" inside is a very delightful blend of flavors with just enough caffine to really give it a zing.'

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer(max_df=0.8, min_df=2, stop_words='english')
doc_term_matrix = count_vect.fit_transform(reviews_datasets['Text'].values.astype('U'))

# %%
CountVectorizer?

# %%
doc_term_matrix
# Out:
# <3963x6066 sparse matrix of type '<class 'numpy.int64'>'
# 	with 117305 stored elements in Compressed Sparse Row format>

# %%
print(doc_term_matrix)
# Out:
#   (0, 683)	1
#   (0, 856)	1
#   (0, 1665)	1
#   (0, 2166)	1
#   (0, 4117)	1
#   (0, 2351)	1
#   (0, 4206)	1
#   (0, 4115)	2
#   (0, 3132)	1
#   (0, 3062)	1
#   (0, 5144)	1
#   (0, 4106)	1
#   (0, 3293)	1
#   (0, 4910)	1
#   (0, 591)	2
#   (0, 2957)	1
#   (0, 2088)	1
#   (0, 358)	1
#   (1, 4115)	2
#   (1, 381)	1
#   (1, 2954)	1
#   (1, 2876)	2
#   (1, 4595)	1
#   (1, 3826)	2
#   (1, 188)	1
#   :	:
#   (3959, 3207)	1
#   (3959, 3527)	1
#   (3960, 2110)	1
#   (3960, 4077)	1
#   (3960, 1103)	1
#   (3960, 589)	2
#   (3960, 705)	1
#   (3960, 1393)	1
#   (3960, 3527)	1
#   (3960, 1448)	1
#   (3961, 591)	1
#   (3961, 1481)	1
#   (3961, 3147)	1
#   (3961, 5994)	1
#   (3961, 6001)	1
#   (3961, 1103)	2
#   (3961, 589)	1
#   (3961, 1721)	1
#   (3961, 5385)	1
#   (3961, 2606)	1
#   (3961, 1393)	1
#   (3961, 4294)	1
#   (3961, 1456)	1
#   (3961, 3960)	1
#   (3961, 2557)	1

# %%
from sklearn.decomposition import LatentDirichletAllocation
LDA = LatentDirichletAllocation(n_components=5, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %%
import random

for i in range(10):
  random_id = random.randint(0,len(count_vect.get_feature_names_out()))
  print(count_vect.get_feature_names_out()[random_id])
# Out:
# sesame
# compares
# girl
# jalapenos
# pitbull
# fiber
# tee
# eastern
# block
# canin

# %%
first_topic = LDA.components_[0]

# %%
top_topic_words = first_topic.argsort()[-10:]

# %%
for i in top_topic_words:
  print(count_vect.get_feature_names_out()[i])
# Out:
# use
# eat
# sugar
# great
# good
# just
# food
# product
# like
# br

# %%
for i,topic in enumerate(LDA.components_):
  print(f'Top 10 words for topic #{i}:')
  print([count_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
  print('\n')
# Out:
# Top 10 words for topic #0:
# ['use', 'eat', 'sugar', 'great', 'good', 'just', 'food', 'product', 'like', 'br']
#
#
# Top 10 words for topic #1:
# ['salt', 'just', 'bag', 'great', 'taste', 'good', 'like', 'flavor', 'br', 'chips']
#
#
# Top 10 words for topic #2:
# ['taste', 'just', 'good', 'meal', 'add', 'like', 'cheese', 'chicken', 'broccoli', 'br']
#
#
# Top 10 words for topic #3:
# ['old', 'product', 'liver', 'loves', 'love', 'treat', 'treats', 'dogs', 'food', 'dog']
#
#
# Top 10 words for topic #4:
# ['taste', 'great', 'good', 'price', 'amazon', 'product', 'tea', 'like', 'br', 'coffee']
